# %%
import pandas as pd
import numpy as np
import math as math
from scipy import stats
import matplotlib.pyplot as plt
from math import *
# %matplotlib inline

# %%
pib_filename = "GDPpercapitaconstant2000US.xlsx"
imp_filename = "Imports (p of GDP).xlsx"
exp_filename = "Exports (p of GDP).xlsx"
idh_filename = "Indicator_HDI.xlsx"

pib = pd.read_excel(pib_filename)
imp = pd.read_excel(imp_filename)
exp = pd.read_excel(exp_filename)
idh = pd.read_excel(idh_filename)

# %%
pib_index = pib.set_index("Income per person (fixed 2000 US$)")
imp_index = imp.set_index("Imports of goods and services (% of GDP)")
exp_index = exp.set_index("Exports of goods and services (% of GDP)")
idh_index = idh.set_index("HDI")

# %% [markdown]
# blablablabla Plot da média do indicado

# %%
a = pib_index.mean()
b = a.index
c = imp_index.mean()
d = c.index
e = exp_index.mean()
f = e.index
g = idh_index.mean()
h = g.index

# %% [markdown]
# blablabla Vamos fazer um plot da média da evolução do indicador *Energy use (per capita)* ao longo do tempo

# %%
plt.figure(figsize=(30,10))
plt.plot(b,a,"r")

plt.figure(figsize=(30,10))
plt.plot(d,c,"r")

plt.figure(figsize=(30,10))
plt.plot(f,e,"r")

plt.figure(figsize=(30,10))
plt.plot(h,g,"r")

# %% [markdown]
# Plot da dispersão ao estilo *Gapminder*

# %%
pib_anos = pib_index.loc[:,('1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977','1978', '1979', '1980', '1981', 
                            '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
                            '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
                            '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
                            '2018')]
pib_trans = pib_anos.transpose()
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:870: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_lowerdim(tup)

# %%
plt.figure(figsize=(30,10))
for pais in pib_trans.columns:
    plt.scatter(x=pib_trans.index, y=pib_trans[pais])

# %%
imp_anos = imp_index.loc[:,('1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977','1978', '1979', '1980', '1981', 
                            '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
                            '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
                            '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
                            '2018')]
imp_trans = imp_anos.transpose()

# %%
plt.figure(figsize=(30,10))
for pais in imp_trans.columns:
    plt.scatter(x=imp_trans.index, y=imp_trans[pais])

# %%
exp_anos = exp_index.loc[:,('1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977','1978', '1979', '1980', '1981', 
                            '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993',
                            '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
                            '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
                            '2018')]
exp_trans = exp_anos.transpose()

# %%
plt.figure(figsize=(30,10))
for pais in exp_trans.columns:
    plt.scatter(x=exp_trans.index, y=exp_trans[pais])

# %%
idh_anos = idh_index.loc[:,(1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,1978, 1979, 1980, 1981, 
                            1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993,
                            1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005,
                            2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017,
                            2018)]
idh_trans = idh_anos.transpose()

# %%
plt.figure(figsize=(30,10))
for pais in idh_trans.columns:
    plt.scatter(x=idh_trans.index, y=idh_trans[pais])

# %%
pib_datas = ['1970',
       '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
       '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
       '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
       '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
       '2007', '2008', '2009', '2010', '2011']

# %%
pib_anos = pib_index.loc[:, pib_datas]

# %%
pib_anos_t = pib_anos.T

# %%
medias_pib = pib_anos.mean()
plt.figure(figsize=(20,10))
for pais in pib_anos_t.columns:
    plt.scatter(x=pib_anos_t.index, y=pib_anos_t[pais])
plt.plot(medias_pib.index,  medias_pib, color="r")

# %%
imp_datas = ['1970',
       '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
       '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
       '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
       '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
       '2007', '2008', '2009', '2010', '2011']

# %%
imp_anos = imp_index.loc[:, imp_datas]
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
imp_anos_t = imp_anos.T

# %%
medias_imp = imp_anos.mean()
plt.figure(figsize=(20,10))
for pais in imp_anos_t.columns:
    plt.scatter(x=imp_anos_t.index, y=imp_anos_t[pais])
plt.plot(medias_imp.index,  medias_imp, color="r")

# %%
exp_datas = ['1970',
       '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
       '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
       '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
       '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
       '2007', '2008', '2009', '2010', '2011']

# %%
exp_anos = exp_index.loc[:, exp_datas]

# %%
exp_anos_t = exp_anos.T

# %%
medias_exp = exp_anos.mean()
plt.figure(figsize=(20,10))
for pais in exp_anos_t.columns:
    plt.scatter(x=exp_anos_t.index, y=exp_anos_t[pais])
plt.plot(medias_exp.index,  medias_exp, color="r")

# %%
idh_datas = [1980, 1990, 2000, 2005, 2006, 2007, 2008, 2009, 2011]

# %%
idh_anos = idh_index.loc[:, idh_datas]

# %%
idh_anos_t = idh_anos.T

# %%
medias_idh = idh_anos.mean()
plt.figure(figsize=(20,10))
for pais in idh_anos_t.columns:
    plt.scatter(x=idh_anos_t.index, y=idh_anos_t[pais])
plt.plot(medias_idh.index,  medias_idh, color="r")

# %% [markdown]
# lista de paises asia

# %%
asia = ['Armenia', 'Azerbaijan', 'Bahrain', 'Bangladesh', 'Bhutan', 'Brunei', 'Cambodia', 'China', 
        'Cyprus', 'Georgia', 'India', 'Indonesia', 'Iran', 'Israel',
        'Japan', 'Jordan', 'Kuwait', 'Lebanon', 'Malaysia', 'Maldives', 'Mongolia', 'Nepal','Oman', 'Pakistan', 'Philippines', 'Qatar', 'Russia', 'Saudi Arabia', 'Singapore', 'Sri Lanka',
        'Syria', 'Tajikistan', 'Thailand', 'Turkey', 'Turkmenistan', 'United Arab Emirates', 'Uzbekistan', 'Vietnam']

# %%
pib_index.loc[:,"Asia"] = "não"
imp_index.loc[:,"Asia"] = "não"
exp_index.loc[:,"Asia"] = "não"
idh_index.loc[:,"Asia"] = "não"

# %%
pib_index.loc[asia, "Asia"] = "sim"
imp_index.loc[asia, "Asia"] = "sim"
exp_index.loc[asia, "Asia"] = "sim"
idh_index.loc[asia, "Asia"] = "sim"

# %%
pib_index
# Out:
#                                             1960          1961          1962  \
# Income per person (fixed 2000 US$)
# Abkhazia                                     NaN           NaN           NaN
# Afghanistan                                  NaN           NaN           NaN
# Akrotiri and Dhekelia                        NaN           NaN           NaN
# Albania                                      NaN           NaN           NaN
# Algeria                              1280.384828   1085.414612    855.947986
# American Samoa                               NaN           NaN           NaN
# Andorra                                      NaN           NaN           NaN
# Angola                                       NaN           NaN           NaN
# Anguilla                                     NaN           NaN           NaN
# Antigua and Barbuda                          NaN           NaN           NaN
# Argentina                            5251.876754   5448.303627   5316.578969
# ...

# %% [markdown]
# Análise para um dado ano

# %%
pib_a = pib_index
imp_a = imp_index
exp_a = exp_index
idh_a = idh_index

# %%
imp_a.Asia.value_counts()
# Out:
# não    175
# sim     38
# Name: Asia, dtype: int64

# %%
exp_a.Asia.value_counts()
# Out:
# não    237
# sim     38
# Name: Asia, dtype: int64

# %%
pib_a.boxplot(column="2005", by="Asia")

# %%
exp_a.Asia.value_counts()
# Out:
# não    237
# sim     38
# Name: Asia, dtype: int64

# %%
imp_a.boxplot(column="2005", by="Asia")

# %%
exp_a.boxplot(column="2005", by="Asia")

# %%
idh_a.boxplot(column=2005, by="Asia")

# %% [markdown]
# Podemos enxergar os mesmos dados via histogramas

# %%
pib_a.hist(column="2005", by="Asia");

# %%
imp_a.hist(column="2005", by="Asia");

# %%
exp_a.hist(column="2005", by="Asia");

# %%
idh_a.hist(column=2005, by="Asia");

# %% [markdown]
# Para o mesmo ano, vamos fazer a **dispersão** comparando as duas tabelas e  os dois subgrupos

# %%
pib_a.Asia.value_counts()
# Out:
# não    237
# sim     38
# Name: Asia, dtype: int64

# %%
exp_a.Asia.value_counts()
# Out:
# não    237
# sim     38
# Name: Asia, dtype: int64

# %%
plt.scatter(pib_a.loc[pib_a.Asia=="sim","2005"], exp_a.loc[exp_a.Asia=="sim", "2005"], color="r")
plt.scatter(pib_a.loc[pib_a.Asia=="não","2005"], exp_a.loc[exp_a.Asia=="não", "2005"], color="b")

# %% [markdown]
# ## Ajuste de retas

# %%
def reta(dados_x, dados_y, c):    
    a = dados_y.cov(dados_x) / dados_x.var()
    b = dados_y.mean() - a*dados_x.mean()

    print('Ajuste linear entre X3 e X4:')
    print('Coeficiente linear:', b)
    print('Coeficiente angular:', a)
    plt.scatter(dados_x, dados_y, c=c, alpha=0.8)
    plt.title('x versus y')
    plt.xlabel('eixo x')
    plt.ylabel('eixo y')

    plt.plot((dados_x.min(), dados_x.max()), (a*dados_x.min()+b, a*dados_x.max()+b), color=c)

    plt.tight_layout()

# %% [markdown]
# Dispersão **mais** ajuste de retas

# %%
plt.scatter(pib_a.loc[pib_a.Asia=="sim","2005"], exp_a.loc[exp_a.Asia=="sim", "2005"], color="r")
reta(pib_a.loc[pib_a.Asia=="sim","2005"], exp_a.loc[exp_a.Asia=="sim", "2005"], "r")
plt.scatter(pib_a.loc[pib_a.Asia=="não","2005"], exp_a.loc[exp_a.Asia=="não", "2005"], color="b")
reta(pib_a.loc[pib_a.Asia=="não","2005"], exp_a.loc[exp_a.Asia=="não", "2005"], "g")
# Out:
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 42.00029489834199
# Coeficiente angular: 0.0012856776748342263
# Ajuste linear entre X3 e X4:
# Coeficiente linear: 38.618437356304966
# Coeficiente angular: 0.00045000152991806137
